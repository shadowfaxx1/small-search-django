# %%
import pandas as pd 

path = r"C:\Users\mail2\Documents\lpth\.vscode\DataSciencePrac\projects\BackendProjects\project4\app\searchapp\static\searchapp\restaurants_small.csv"
df = pd.read_csv(path)

df
# Out:
#         id                     name                    location  \
# 0    11116       Udupi Thaja Thindi                         BTM
# 1     9851                 Momo Hut       Koramangala 5th Block
# 2     8380        Chandrika Tiffins                  Whitefield
# 3     8462             Shuchi Ruchi                Malleshwaram
# 4     8466         Smiley's Kitchen       Koramangala 1st Block
# ..     ...                      ...                         ...
# 495   8087              hwealthcafe                         HSR
# 496  10038       Sree Food Paradise                         BTM
# 497   9553  Gurukrupa Paratha House                      Domlur
# 498   9980       Hotel Shreekshetra               Sarjapur Road
# 499  11042          Behrouz Biryani  ITPL Main Road, Whitefield
#
#                                                  items  \
# 0    {"2 Idli with 1 Vada": "60.00 ", "Masala Dosa"...
# 1    {"Steamed Veg Momos": "90.00 ", "Steamed Chick...
# ...

# %%
print(len(items_set))
# Out:
# 25206
